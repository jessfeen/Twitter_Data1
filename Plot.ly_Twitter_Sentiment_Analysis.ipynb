# %%
# Get this figure: fig = py.get_figure("https://plot.ly/~susmithcall2/2/")
# Get this figure's data: data = py.get_figure("https://plot.ly/~susmithcall2/2/").get_data()
# Add data to this figure: py.plot(Data([Scatter(x=[1, 2], y=[2, 3])]), filename ="tweet_stream_analysis", fileopt="extend")

# Get figure documentation: https://plot.ly/python/get-requests/
# Add data documentation: https://plot.ly/python/file-options/

# If you're using unicode in your file, you may need to specify the encoding.
# You can reproduce this figure in Python with the following code!

# Learn about API authentication here: https://plot.ly/python/getting-started
# Find your api_key here: https://plot.ly/settings/api

import plotly.plotly as py
from plotly.graph_objs import *
py.sign_in('username', 'api_key')
trace1 = {
  "marker": {
    "color": "rgba(0, 255, 0, .8)", 
    "line": {
      "color": "rgb(0, 0, 0)", 
      "width": 2
    }, 
    "size": 20
  }, 
  "mode": "lines+markers", 
  "stream": {
    "maxpoints": 1080, 
    "token": "your_stream_token_here"
  }, 
  "type": "scatter"
}
trace2 = {
  "marker": {
    "color": "rgba(255, 0, 0, .8)", 
    "line": {
      "color": "rgb(0, 0, 0)", 
      "width": 2
    }, 
    "size": 20
  }, 
  "mode": "lines+markers", 
  "stream": {
    "maxpoints": 1080, 
    "token": "your_stream_token_here"
  }, 
  "type": "scatter"
}
trace3 = {
  "marker": {
    "color": "rgba(192, 192, 192, .8)", 
    "line": {
      "color": "rgb(0, 0, 0)", 
      "width": 2
    }, 
    "size": 20
  }, 
  "mode": "lines+markers", 
  "stream": {
    "maxpoints": 1080, 
    "token": "your_stream_token_here"
  }, 
  "type": "scatter"
}
data = Data([trace1, trace2, trace3])
layout = {"title": "Twitter Stream Sentiment Analysis (Created_time vs Sentiment)"}
fig = Figure(data=data, layout=layout)
plot_url = py.plot(fig)
